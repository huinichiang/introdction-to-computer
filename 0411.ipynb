# %% [markdown]
# <a href="https://colab.research.google.com/github/huinichiang/introdction-to-computer/blob/main/0411.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
# Out:
# hi

# %%
not(3<5)
# Out:
# False

# %% [markdown]
# ![S__2416645.jpg](data:image/jpeg;base64,...)

# %%
i=10

# %%
i+=5

# %%
i
# Out:
# 15

# %%
i-=5
i
# Out:
# 10

# %%
i=10

# %%
i-=5
i
# Out:
# 5

# %%
i=10
i*=5
i
# Out:
# 50

# %%
i=10
i/=5
i
# Out:
# 2.0

# %%
print(1+2)
# Out:
# 3

# %%
print('1'+'2')
# Out:
# 12

# %%
print('你'+'好'+'!')
# Out:
# 你好!

# %%
deposit=int(input('請輸入本金存款金額:'))
years=1.02**6
deposit *=years
print('6年後存款為:'+str(deposit))
# Out:
# 請輸入本金存款金額:1000
# 6年後存款為:1126.1624192640002

# %%
pw=input('請輸入密碼')
if(pw=='1234'):
  print('歡迎光臨!')
else:
  print('密碼錯誤!')
# Out:
# 請輸入密碼1256
# 密碼錯誤!

# %%
rain=input("今天會下雨嗎?")
if(rain=="Y" or rain=="y"):
  print("出門記得帶傘!出門記得帶傘!")
# Out:
# 今天會下雨嗎?y
# 出門記得帶傘!出門記得帶傘!

# %%
num=int(input("輸入一個數字:"))
if(num%2)==0:
  print("{0} 是偶數".format(num))
else:
  print("{0} 是奇數".format(num))
# Out:
# 輸入一個數字:2
# 2 是偶數
